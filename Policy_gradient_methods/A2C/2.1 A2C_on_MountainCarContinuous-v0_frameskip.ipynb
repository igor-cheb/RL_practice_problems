# %%
import gym
import numpy as np

import matplotlib.pyplot as plt
from IPython.display import clear_output
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback
import torch
from torch import nn

from stable_baselines3 import A2C
from stable_baselines3.common.monitor import Monitor
from rl_zoo3.wrappers import FrameSkip

# %%
env_name = 'MountainCarContinuous-v0'

# %% [markdown]
# # MountainCarContinuous SB3 A2C baseline

# %% [markdown]
# Let's establish a baseline using sb3 and rl_zoo3 libraries. We will be using frameskip wrapper from rl_zoo3. This environment needs it to enable stable convergence.

# %%
env = make_vec_env(env_name, 
                   n_envs=8, 
                   wrapper_class=FrameSkip)

# %%
model = A2C("MlpPolicy", env, verbose=1, 
            n_steps=30,
            ent_coef=0.0001)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=1e6)
# Out:
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 680      |
# |    ep_rew_mean        | 40.3     |
# | time/                 |          |
# |    fps                | 10187    |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.0118   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.336    |
# |    std                | 0.979    |
# |    value_loss         | 317      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 669      |
# |    ep_rew_mean        | 18.4     |
# | time/                 |          |
# |    fps                | 10224    |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.123   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -7.13    |
# |    std                | 0.967    |
# |    value_loss         | 34.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 802      |
# |    ep_rew_mean        | -26.3    |
# | time/                 |          |
# |    fps                | 10231    |
# |    iterations         | 300      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.456   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -6.29    |
# |    std                | 0.971    |
# |    value_loss         | 45.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 834      |
# |    ep_rew_mean        | -36.2    |
# | time/                 |          |
# |    fps                | 10232    |
# |    iterations         | 400      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.989   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -5.6     |
# |    std                | 0.964    |
# |    value_loss         | 30.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 815      |
# |    ep_rew_mean        | -25.8    |
# | time/                 |          |
# |    fps                | 10223    |
# |    iterations         | 500      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -0.371   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -4.2     |
# |    std                | 0.967    |
# |    value_loss         | 19.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 769      |
# |    ep_rew_mean        | -25      |
# | time/                 |          |
# |    fps                | 10207    |
# |    iterations         | 600      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.109    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 10.5     |
# |    std                | 0.973    |
# |    value_loss         | 977      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 790      |
# |    ep_rew_mean        | -21.5    |
# | time/                 |          |
# |    fps                | 10202    |
# |    iterations         | 700      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 168000   |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.126    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 8.49     |
# |    std                | 0.986    |
# |    value_loss         | 906      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 769      |
# |    ep_rew_mean        | -14      |
# | time/                 |          |
# |    fps                | 10202    |
# |    iterations         | 800      |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.228    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 7.22     |
# |    std                | 0.992    |
# |    value_loss         | 500      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 635      |
# |    ep_rew_mean        | 19       |
# | time/                 |          |
# |    fps                | 10195    |
# |    iterations         | 900      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 216000   |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.178    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 7.95     |
# |    std                | 0.981    |
# |    value_loss         | 894      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 699      |
# |    ep_rew_mean        | -0.351   |
# | time/                 |          |
# |    fps                | 10196    |
# |    iterations         | 1000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 240000   |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.288    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 9.62     |
# |    std                | 0.977    |
# |    value_loss         | 415      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 488      |
# |    ep_rew_mean        | 54.6     |
# | time/                 |          |
# |    fps                | 10193    |
# |    iterations         | 1100     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 264000   |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.357    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 1.7      |
# |    std                | 0.99     |
# |    value_loss         | 596      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 537      |
# |    ep_rew_mean        | 37.1     |
# | time/                 |          |
# |    fps                | 10195    |
# |    iterations         | 1200     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.122    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 23.6     |
# |    std                | 0.994    |
# |    value_loss         | 1.48e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 398      |
# |    ep_rew_mean        | 67.4     |
# | time/                 |          |
# |    fps                | 10190    |
# |    iterations         | 1300     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 312000   |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.137    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 9.97     |
# |    std                | 0.987    |
# |    value_loss         | 948      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 362      |
# |    ep_rew_mean        | 70.2     |
# | time/                 |          |
# |    fps                | 10193    |
# |    iterations         | 1400     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 336000   |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.0151   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 19.2     |
# |    std                | 0.997    |
# |    value_loss         | 1.31e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 335      |
# |    ep_rew_mean        | 76.4     |
# | time/                 |          |
# |    fps                | 10193    |
# |    iterations         | 1500     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 360000   |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.0048   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 14       |
# |    std                | 0.998    |
# |    value_loss         | 1.13e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 326      |
# |    ep_rew_mean        | 74.8     |
# | time/                 |          |
# |    fps                | 10190    |
# |    iterations         | 1600     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 384000   |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | -0.0023  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 8.96     |
# |    std                | 0.994    |
# |    value_loss         | 940      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 252      |
# |    ep_rew_mean        | 83.2     |
# | time/                 |          |
# |    fps                | 10189    |
# |    iterations         | 1700     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 408000   |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.00187  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 16.8     |
# |    std                | 0.999    |
# |    value_loss         | 1.21e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 244      |
# |    ep_rew_mean        | 82.8     |
# | time/                 |          |
# |    fps                | 10191    |
# |    iterations         | 1800     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 432000   |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | 0.000167 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 21       |
# |    std                | 1        |
# |    value_loss         | 1.31e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 264      |
# |    ep_rew_mean        | 79.1     |
# | time/                 |          |
# |    fps                | 10187    |
# |    iterations         | 1900     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 456000   |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.000292 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -1.46    |
# |    std                | 0.996    |
# |    value_loss         | 426      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 257      |
# |    ep_rew_mean        | 79.8     |
# | time/                 |          |
# |    fps                | 10191    |
# |    iterations         | 2000     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 480000   |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.000532 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 4.65     |
# |    std                | 0.994    |
# |    value_loss         | 687      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 199      |
# |    ep_rew_mean        | 86.7     |
# | time/                 |          |
# |    fps                | 10194    |
# |    iterations         | 2100     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 504000   |
# | train/                |          |
# |    entropy_loss       | -1.41    |
# |    explained_variance | 0.000245 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 2.49     |
# |    std                | 0.991    |
# |    value_loss         | 556      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 210      |
# |    ep_rew_mean        | 85.5     |
# | time/                 |          |
# |    fps                | 10192    |
# |    iterations         | 2200     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 528000   |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.000217 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 23.6     |
# |    std                | 0.986    |
# |    value_loss         | 1.14e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | 85.4     |
# | time/                 |          |
# |    fps                | 10196    |
# |    iterations         | 2300     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 552000   |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.000115 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 17.5     |
# |    std                | 0.976    |
# |    value_loss         | 849      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 184      |
# |    ep_rew_mean        | 87       |
# | time/                 |          |
# |    fps                | 10194    |
# |    iterations         | 2400     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 576000   |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 6.5e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 15.5     |
# |    std                | 0.97     |
# |    value_loss         | 800      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 186      |
# |    ep_rew_mean        | 86       |
# | time/                 |          |
# |    fps                | 10195    |
# |    iterations         | 2500     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 600000   |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.000167 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 13.4     |
# |    std                | 0.948    |
# |    value_loss         | 726      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 167      |
# |    ep_rew_mean        | 87.4     |
# | time/                 |          |
# |    fps                | 10194    |
# |    iterations         | 2600     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 624000   |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 8.85e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 12.7     |
# |    std                | 0.953    |
# |    value_loss         | 646      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 149      |
# |    ep_rew_mean        | 90       |
# | time/                 |          |
# |    fps                | 10193    |
# |    iterations         | 2700     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 648000   |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 8.25e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.152    |
# |    std                | 0.949    |
# |    value_loss         | 359      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 143      |
# |    ep_rew_mean        | 90.7     |
# | time/                 |          |
# |    fps                | 10192    |
# |    iterations         | 2800     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 672000   |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 3.92e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 10.4     |
# |    std                | 0.94     |
# |    value_loss         | 447      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 136       |
# |    ep_rew_mean        | 91        |
# | time/                 |           |
# |    fps                | 10192     |
# |    iterations         | 2900      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 696000    |
# | train/                |           |
# |    entropy_loss       | -1.35     |
# |    explained_variance | -7.03e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -0.258    |
# |    std                | 0.934     |
# |    value_loss         | 302       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 128      |
# |    ep_rew_mean        | 91.3     |
# | time/                 |          |
# |    fps                | 10189    |
# |    iterations         | 3000     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 720000   |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 3.95e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 12.6     |
# |    std                | 0.929    |
# |    value_loss         | 328      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 121      |
# |    ep_rew_mean        | 91       |
# | time/                 |          |
# |    fps                | 10179    |
# |    iterations         | 3100     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 744000   |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 2.8e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 7        |
# |    std                | 0.921    |
# |    value_loss         | 235      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 107      |
# |    ep_rew_mean        | 92.1     |
# | time/                 |          |
# |    fps                | 10173    |
# |    iterations         | 3200     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 768000   |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | 0.000182 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 4.2      |
# |    std                | 0.907    |
# |    value_loss         | 193      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 96.9     |
# |    ep_rew_mean        | 92.4     |
# | time/                 |          |
# |    fps                | 10169    |
# |    iterations         | 3300     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 792000   |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.0106   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 4.23     |
# |    std                | 0.895    |
# |    value_loss         | 176      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 97.4     |
# |    ep_rew_mean        | 92.4     |
# | time/                 |          |
# |    fps                | 10163    |
# |    iterations         | 3400     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 816000   |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0.0753   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 6.4      |
# |    std                | 0.882    |
# |    value_loss         | 112      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90       |
# |    ep_rew_mean        | 92.6     |
# | time/                 |          |
# |    fps                | 10160    |
# |    iterations         | 3500     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 840000   |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.119    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -1.05    |
# |    std                | 0.874    |
# |    value_loss         | 160      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 91.6     |
# |    ep_rew_mean        | 92.5     |
# | time/                 |          |
# |    fps                | 10158    |
# |    iterations         | 3600     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 864000   |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 0.207    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 1.9      |
# |    std                | 0.861    |
# |    value_loss         | 70.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.5     |
# |    ep_rew_mean        | 92.6     |
# | time/                 |          |
# |    fps                | 10153    |
# |    iterations         | 3700     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 888000   |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.296    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 2.32     |
# |    std                | 0.854    |
# |    value_loss         | 72       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 92.5     |
# |    ep_rew_mean        | 92.7     |
# | time/                 |          |
# |    fps                | 10153    |
# |    iterations         | 3800     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 912000   |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | 0.217    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.812    |
# |    std                | 0.846    |
# |    value_loss         | 85.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 83.6     |
# |    ep_rew_mean        | 92.9     |
# | time/                 |          |
# |    fps                | 10146    |
# |    iterations         | 3900     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 936000   |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | 0.0992   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -3.14    |
# |    std                | 0.843    |
# |    value_loss         | 106      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 85.5     |
# |    ep_rew_mean        | 92.7     |
# | time/                 |          |
# |    fps                | 10142    |
# |    iterations         | 4000     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 960000   |
# | train/                |          |
# |    entropy_loss       | -1.24    |
# |    explained_variance | 0.452    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 1.36     |
# |    std                | 0.832    |
# |    value_loss         | 40.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84.6     |
# |    ep_rew_mean        | 92.6     |
# | time/                 |          |
# |    fps                | 10135    |
# |    iterations         | 4100     |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 984000   |
# | train/                |          |
# |    entropy_loss       | -1.22    |
# |    explained_variance | 0.554    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 1.44     |
# |    std                | 0.821    |
# |    value_loss         | 31.6     |
# ------------------------------------

# %%
test_env = make_vec_env(env_name, n_envs=1)

# %%
def eval_agent(env, actor, n_steps=1000, render=True):
    state = env.reset()

    rewards, logits = [], []
    for _ in range(n_steps):
        if render:
            env.render()

        action = actor.predict(state)
        next_state, reward, done, info = env.step(action[0])

        rewards.append(reward)

        state = next_state
        if done:
            break

    env.close()
    return sum(rewards)

# %%
eval_agent(test_env, model, n_steps=1000, render=True)
# Out:
# array([93.09493], dtype=float32)

# %% [markdown]
# The model converges to rewards around 90 within 1e6 steps. Let's now try to repeat the result using DIY functionality.

# %% [markdown]
# # DIY A2C on MountainCarContinuous-v0 with frameskip

# %%
env = gym.make(env_name)
envs = make_vec_env(env_name, n_envs=8, 
                   wrapper_class=FrameSkip)#batch_agent_not_mc(env_name=env_name, n_envs=3)

init_observation = env.reset()
state_len = len(env.reset())
action_len = len(env.action_space.sample())

DISCOUNT = 0.99

# %%
num_inputs  = envs.observation_space.shape[0]
num_outputs = len(envs.action_space.sample())

# %%
class Actor(torch.nn.Module):
    
    def __init__(self, obs_len=state_len, action_len=action_len):
        super().__init__()
        self.obs_len = obs_len
        self.action_len = action_len
        
        self.lin_1 = torch.nn.Linear(self.obs_len, 256)
        self.rel_1 = torch.nn.ReLU()

        self.lin_2 = torch.nn.Linear(256, self.action_len)
        
        self.lin_3 = torch.nn.Linear(256, self.action_len)
        self.elu = torch.nn.ELU()
        
        
    def forward(self, x):
        x = self.lin_1(x)
        x = self.rel_1(x)

        mu = self.lin_2(x)
        
        x = self.lin_3(x)
        sigma = self.elu(x) + 1.000001
        
        return mu, sigma
    
    def act(self, observation):
        (mu, sigma) = self.forward(observation)
        dist = torch.distributions.normal.Normal(mu, sigma)
        action = dist.sample()
        logit = dist.log_prob(action)   
        entropy = dist.entropy()
        return action, logit, entropy
    

class Critic(torch.nn.Module):
    
    def __init__(self, obs_len=state_len):
        super().__init__()
        self.obs_len = obs_len
        self.lin_1 = torch.nn.Linear(self.obs_len, 256)
        self.rel_1 = torch.nn.ReLU()
        self.drop = torch.nn.Dropout(p=0.15)
        self.lin_2 = torch.nn.Linear(256, 1)
    
    def forward(self, x):
        x = self.lin_1(x)
        x = self.rel_1(x)
        x = self.drop(x)
        x = self.lin_2(x)
        return x

# %%
def eval_agent(actor, n_steps=300, render=True):
    state = env.reset()

    rewards, logits = [], []
    for _ in range(n_steps):
        if render:
            env.render()

        action, _, _ = actor.act(torch.tensor(state, dtype=torch.float32))
        next_state, reward, done, info = env.step([action.detach().numpy()[0]])

        rewards.append(reward)

        state = next_state
        if done:
            break

    env.close()
    return sum(rewards)

def calc_cum_rewards(next_state_vals, rewards, dones, discount=DISCOUNT):
    res = []
    G = next_state_vals.T
    for done, el in zip(dones.flip(0), rewards.flip(0)):
        G = el + discount * G * done
        res.insert(0, G)
    return torch.stack(res).squeeze()

def calc_losses(rewards, state_values, next_state_value, logits, entropies, dones, DISCOUNT):
    rewards = torch.tensor(rewards, dtype=torch.float32)
    dones = torch.tensor(dones, dtype=torch.float32).squeeze()

    cum_rewards = calc_cum_rewards(next_state_value, rewards, dones, discount=DISCOUNT)
    stacked_state_values = torch.stack(state_values).squeeze()
    stacked_logits = torch.stack(logits).squeeze()

    entropy = torch.stack(entropies).sum()

    advantage = (cum_rewards - stacked_state_values).detach()
    actor_loss =  - (stacked_logits * advantage).mean() - 0.0001 * entropy.mean()
    critic_loss = torch.nn.functional.mse_loss(cum_rewards, 
                                               stacked_state_values)
    return actor_loss, critic_loss

def learn_one_traj(actor, critic, actor_opt, critic_opt, 
               traj_length=20, n_steps=200, discount=DISCOUNT):
    state =  envs.reset()
    states, rewards, logits, state_values, entropies, \
    next_state_values, dones, actor_losses, critic_losses = [], [], [], [], [], [], [], [], []
    for step in range(n_steps):

        #we get the action from the actor
        action, logit, entropy = actor.act(torch.tensor(state, dtype=torch.float32))

        #use the action to make a step by the env
        next_state, reward, done, info = envs.step(action) #.detach().numpy()
        
        # getting state and next state values from critic
        state_value = critic(torch.tensor(state, dtype=torch.float32))
        next_state_value = critic(torch.tensor(next_state, dtype=torch.float32))

        entropies.append(entropy)
        rewards.append(reward)
        logits.append(logit)
        state_values.append(state_value)
        next_state_values.append(next_state_value)

        dones.append(1 - np.array(done))

        state = next_state

        # calculate losses if we made enough steps for 1 trajectory
        if (step % traj_length == 0) and step > 1:
            if len(next_state_value.shape) < 2: next_state_value = next_state_value.unsqueeze(0)
            actor_loss, critic_loss = calc_losses(rewards[-traj_length:], 
                                                  state_values[-traj_length:], 
                                                  next_state_value, 
                                                  logits[-traj_length:],
                                                  entropies[-traj_length:],
                                                  dones[-traj_length:],
                                                  discount)
            actor_losses.append(actor_loss)
            critic_losses.append(critic_loss)

            actor_opt.zero_grad()
            actor_loss.backward()
            actor_opt.step()

            critic_opt.zero_grad()
            critic_loss.backward()
            critic_opt.step()

    out = (states, rewards, logits, state_values, next_state_values, dones, 
           actor_losses, critic_losses, entropies)
    return out

# %%
actor = Actor()
critic = Critic()
lr = 7e-4
actor_opt = torch.optim.Adam(actor.parameters(),   lr=lr)
critic_opt = torch.optim.Adam(critic.parameters(), lr=lr)

# %%
mean_rewards, all_actor_losses, all_critic_losses, mean_critic_losses, mean_actor_losses = \
    [], [], [], [], []

for ep in range(int(2e3)): #
    states, rewards, logits, state_values, next_state_values, dones, actor_losses, critic_losses, entropies = \
            learn_one_traj(actor, critic, actor_opt, critic_opt, traj_length=50, n_steps=500)
    
    
    ################## progress plotting ##################
    all_actor_losses.append(torch.stack(actor_losses).median().detach().numpy())
    all_critic_losses.append(torch.stack(critic_losses).median().detach().numpy())
    
    ave_over=10
    if ep%ave_over==0:
        mean_critic_losses.append(np.median(all_critic_losses[-ave_over:]))
        mean_actor_losses.append(np.median(all_actor_losses[-ave_over:]))
        mean_rewards.append(np.median([eval_agent(actor, n_steps=1000, render=False) for _ in range(30)]))
        
        clear_output()
        fig, ax = plt.subplots(1, 3, figsize=(20, 6))
        ax[0].plot(mean_rewards); ax[0].set_title(f'Mean_rewards, ep.: {ep}')
        ax[0].hlines(0, 0, len(mean_rewards), color='red')
        ax[0].hlines(70, 0, len(mean_rewards), color='orange')
        ax[0].hlines(90, 0, len(mean_rewards), color='green')
        
        ax[1].plot(mean_actor_losses); ax[1].set_title('Mean_actor_losses')
        ax[2].plot(mean_critic_losses); ax[2].set_title('Mean_critic_losses')
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 6
#       1 # mean_rewards, all_actor_losses, all_critic_losses, mean_critic_losses, mean_actor_losses = \
#       2 #     [], [], [], [], []
#       4 for ep in range(int(2e3)): #
#       5     states, rewards, logits, state_values, next_state_values, dones, actor_losses, critic_losses, entropies = \
# ----> 6             learn_one_traj(actor, critic, actor_opt, critic_opt, traj_length=50, n_steps=500)
#       9     ################## progress plotting ##################
#      10     all_actor_losses.append(torch.stack(actor_losses).median().detach().numpy())
#
# Cell In[40], line 57, in learn_one_traj(actor, critic, actor_opt, critic_opt, traj_length, n_steps, discount)
#      53         action, logit, entropy = actor.act(torch.tensor(state, dtype=torch.float32))
#      54 #         print(action)
#      55
#      56         #use the action to make a step by the env
# ---> 57         next_state, reward, done, info = envs.step(action) #.detach().numpy()
#      59         # getting state and next state values from critic
#      60         state_value = critic(torch.tensor(state, dtype=torch.float32))
#
# File ~/.local/share/virtualenvs/RL_in_ksp--361CVkw/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:163, in VecEnv.step(self, actions)
#     156 """
#     157 Step the environments with the given action
#     158
#     159 :param actions: the action
#     160 :return: observation, reward, done, information
#     161 """
#     162 self.step_async(actions)
# --> 163 return self.step_wait()
#
# File ~/.local/share/virtualenvs/RL_in_ksp--361CVkw/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:54, in DummyVecEnv.step_wait(self)
#      52 def step_wait(self) -> VecEnvStepReturn:
#      53     for env_idx in range(self.num_envs):
# ---> 54         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      55             self.actions[env_idx]
#      56         )
#      57         if self.buf_dones[env_idx]:
#      58             # save final observation where user can get it, then reset
#      59             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~/.local/share/virtualenvs/RL_in_ksp--361CVkw/lib/python3.9/site-packages/rl_zoo3/wrappers.py:269, in FrameSkip.step(self, action)
#     267 done = None
#     268 for _ in range(self._skip):
# --> 269     obs, reward, done, info = self.env.step(action)
#     270     total_reward += reward
#     271     if done:
#
# File ~/.local/share/virtualenvs/RL_in_ksp--361CVkw/lib/python3.9/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, done, info = self.env.step(action)
#      95 self.rewards.append(reward)
#      96 if done:
#
# File ~/.local/share/virtualenvs/RL_in_ksp--361CVkw/lib/python3.9/site-packages/gym/wrappers/time_limit.py:18, in TimeLimit.step(self, action)
#      14 def step(self, action):
#      15     assert (
#      16         self._elapsed_steps is not None
#      17     ), "Cannot call env.step() before calling reset()"
# ---> 18     observation, reward, done, info = self.env.step(action)
#      19     self._elapsed_steps += 1
#      20     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/.local/share/virtualenvs/RL_in_ksp--361CVkw/lib/python3.9/site-packages/gym/envs/classic_control/continuous_mountain_car.py:120, in Continuous_MountainCarEnv.step(self, action)
#     117     reward = 100.0
#     118 reward -= math.pow(action[0], 2) * 0.1
# --> 120 self.state = np.array([position, velocity], dtype=np.float32)
#     121 return self.state, reward, done, {}
#
# File ~/.local/share/virtualenvs/RL_in_ksp--361CVkw/lib/python3.9/site-packages/torch/_tensor.py:958, in Tensor.__array__(self, dtype)
#     956     return self.numpy()
#     957 else:
# --> 958     return self.numpy().astype(dtype, copy=False)
#
# KeyboardInterrupt:

# %% [markdown]
# The agent repeats the baseline results.

# %%
test_res = [eval_agent(actor, n_steps=1000, render=False) for _ in range(1000)]
med = np.median(test_res)
std = np.std(test_res)

# %%
med
# Out:
# 90.98183966439393

# %%
std
# Out:
# 3.323945755031544
